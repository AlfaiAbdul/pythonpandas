# %%
#Dependencies
import pandas as pd
import json

# %%
#Create DataFrames for each set of data
heros1_df = pd.read_json('purchase_data.json')
heros2_df = pd.read_json('purchase_data2.json')

# %%
heros1_df.columns
# Out:
# Index(['Age', 'Gender', 'Item ID', 'Item Name', 'Price', 'SN'], dtype='object')

# %%
heros1_df.head(100)
# Out:
#     Age  Gender  Item ID                                  Item Name  Price  \
# 0    38    Male      165                Bone Crushing Silver Skewer   3.37
# 1    21    Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2    34    Male      174                            Primitive Blade   2.46
# 3    21    Male       92                               Final Critic   1.36
# 4    23    Male       63                             Stormfury Mace   1.27
# 5    20    Male       10                                Sleepwalker   1.73
# 6    20    Male      153                            Mercenary Sabre   4.57
# 7    29  Female      169     Interrogator, Blood Blade of the Queen   3.32
# 8    25    Male      118           Ghost Reaver, Longsword of Magic   2.77
# 9    31    Male       99       Expiration, Warscythe Of Lost Worlds   4.53
# 10   24    Male       57            Despair, Favor of Due Diligence   3.81
# ...

# %% [raw]
# ######Player Count#######

# %%
#Total Number of Players:
total_players = len(heros1_df['SN'])
total_players
# Out:
# 780

# %%
##Purchasing Analysis (Total)##

# %%
#Number of Unique Items:
unique_items = heros1_df['Item ID'].nunique()
#Average Purchase Price for unique Items:
avrg_purchase = heros1_df['Price'].mean()
#avrg_purchase = avrg_purchase.round(2)
#Total Number of Purchases:
total_purchases = len(heros1_df['Price'])
#Total Revenue:
total_revenue = sum(heros1_df['Price'])

# %%
##Purchasing Analysis (Total)##
print("Unique Items: " + str(unique_items))
print("avrg_purchase: " + "$" + str(avrg_purchase))
print("total_purchases: " + str(total_purchases))
print("total_revenue: " + "$" + str(total_revenue))
# Out:
# Unique Items: 183
# avrg_purchase: $2.931192307692303
# total_purchases: 780
# total_revenue: $2286.33

# %%
###Gender Demographics###

# %%
#Percentage and Count of Male Players:

heros1_df['Gender'].nunique()
# Out:
# 3
